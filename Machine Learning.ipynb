# %%
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
world_data=pd.read_excel(Path('c:/users/jrram/Desktop/economic_data.xlsx'))
world_data.head()
# Out:
#    Year  Brazil GDP constant prices (% Change)  \
# 0  2011                                  3.974
# 1  2012                                  1.921
# 2  2013                                  3.005
# 3  2014                                  0.504
# 4  2015                                 -3.546
#
#    Brazil GDP, Current Prices in USD (Billions)  \
# 0                                       2614.03
# 1                                       2464.05
# 2                                       2471.72
# 3                                       2456.06
# 4                                       1800.05
#
#    Brazil Inflation, AVG Consumer Prices %   Brazil Unemployment Rate %  \
# 0                                     6.636                       7.800
# 1                                     5.404                       7.400
# 2                                     6.204                       7.200
# 3                                     6.329                       6.783
# ...

# %%
world_data.drop(columns=['Brazil','China','Turkey','Guatemala','Iran','Nicaragua','Panama'], inplace=True)

# %%
world_data.head()
# Out:
#    Year  Brazil GDP constant prices (% Change)  \
# 0  2011                                  3.974
# 1  2012                                  1.921
# 2  2013                                  3.005
# 3  2014                                  0.504
# 4  2015                                 -3.546
#
#    Brazil GDP, Current Prices in USD (Billions)  \
# 0                                       2614.03
# 1                                       2464.05
# 2                                       2471.72
# 3                                       2456.06
# 4                                       1800.05
#
#    Brazil Inflation, AVG Consumer Prices %   Brazil Unemployment Rate %  \
# 0                                     6.636                       7.800
# 1                                     5.404                       7.400
# 2                                     6.204                       7.200
# 3                                     6.329                       6.783
# ...

# %%
pd.to_numeric(world_data['Brazil GDP constant prices (% Change)'])
# Out:
# 0         3.974
# 1         1.921
# 2         3.005
# 3         0.504
# 4        -3.546
# 5        -3.276
# 6         1.323
# 7         1.784
# 8      1411.000
# 9    -40059.000
# 10        3.655
# Name: Brazil GDP constant prices (% Change), dtype: float64

# %%
world_data['Brazil GDP constant prices (% Change)'][0]
# Out:
# 3.974

# %%
pd.to_numeric(list(world_data.columns[1:]))

# %%
StandardScaler.fit_transform(world_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-f51351316666> in <module>
# ----> 1 StandardScaler.fit_transform(world_data)
#
# TypeError: fit_transform() missing 1 required positional argument: 'X'
